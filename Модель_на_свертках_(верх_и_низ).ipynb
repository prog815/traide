# %% [markdown]
# <a href="https://colab.research.google.com/github/prog815/traide/blob/main/%D0%9C%D0%BE%D0%B4%D0%B5%D0%BB%D1%8C_%D0%BD%D0%B0_%D1%81%D0%B2%D0%B5%D1%80%D1%82%D0%BA%D0%B0%D1%85_(%D0%B2%D0%B5%D1%80%D1%85_%D0%B8_%D0%BD%D0%B8%D0%B7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Подключаем библиотеки

# %%
! pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.63.tar.gz (26 kB)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.9)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 17.5 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23918 sha256=6a61209faa76b94c1640c6afd5f1285b507fbfb9dcc631264d822eedf1b7d998
#   Stored in directory: /root/.cache/pip/wheels/fe/87/8b/7ec24486e001d3926537f5f7801f57a74d181be25b11157983
# Successfully built yfinance
# Installing collected packages: lxml, yfinance
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.6.3 yfinance-0.1.63

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Загрузка котировок

# %% [markdown]
# ## список тикеров

# %%
acc_list = "TGKA	FEES	VTBR	TGKB	HYDR	TGKD	TGKN	RSTI	ENRU	SNGS	MRKV	GAZP	MRKZ	MRKP	SNGSP	MAGN	TGKDP	MSNG	MRKC	MRKU	NMTP	NLMK	MTLR	AFLT	MSRS	ROSN	TTLK	FESH	TRMK	RSTIP	RTKM	SIBN	AMEZ	ISKJ	DVEC	RASP	RTKMP	UTAR	LSNG	BSPB	MRKS	MVID	NKNCP	LSNGP	PIKK	KMAZ	IRKT	SVAV	CHEP	MRKK	KUBE	ROSB	KROT".split('\t')
acc_list = [f'{name}.ME' for name in acc_list]
np.array(acc_list)
# Out:
# array(['TGKA.ME', 'FEES.ME', 'VTBR.ME', 'TGKB.ME', 'HYDR.ME', 'TGKD.ME',
#        'TGKN.ME', 'RSTI.ME', 'ENRU.ME', 'SNGS.ME', 'MRKV.ME', 'GAZP.ME',
#        'MRKZ.ME', 'MRKP.ME', 'SNGSP.ME', 'MAGN.ME', 'TGKDP.ME', 'MSNG.ME',
#        'MRKC.ME', 'MRKU.ME', 'NMTP.ME', 'NLMK.ME', 'MTLR.ME', 'AFLT.ME',
#        'MSRS.ME', 'ROSN.ME', 'TTLK.ME', 'FESH.ME', 'TRMK.ME', 'RSTIP.ME',
#        'RTKM.ME', 'SIBN.ME', 'AMEZ.ME', 'ISKJ.ME', 'DVEC.ME', 'RASP.ME',
#        'RTKMP.ME', 'UTAR.ME', 'LSNG.ME', 'BSPB.ME', 'MRKS.ME', 'MVID.ME',
#        'NKNCP.ME', 'LSNGP.ME', 'PIKK.ME', 'KMAZ.ME', 'IRKT.ME', 'SVAV.ME',
#        'CHEP.ME', 'MRKK.ME', 'KUBE.ME', 'ROSB.ME', 'KROT.ME'], dtype='<U8')

# %% [markdown]
# ## Загрузка из сети

# %%
all_data = yf.download(acc_list,period='10y',threads=False)
# Out:
# [*********************100%***********************]  53 of 53 completed

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2507 entries, 2011-08-17 to 2021-08-17
# Columns: 318 entries, ('Adj Close', 'AFLT.ME') to ('Volume', 'VTBR.ME')
# dtypes: float64(318)
# memory usage: 6.1 MB

# %% [markdown]
# ## Заполнить пустоты предыдущим

# %%
all_data.fillna(method='pad',inplace=True)

# %% [markdown]
# # Подготовка данных

# %% [markdown]
# ## К общему знаменателю (без сдвига)

# %% [markdown]
# ### Входы (курсы + объем) (без сдвига)

# %%
# inpData1 = np.hstack([(all_data[gr] / all_data['Close'].shift(1)).values for gr in ('Open','High','Low','Close')])
# inpData1.shape
d = [all_data[gr]/all_data['Close'].shift(1) for gr in ('Open','High','Low','Close')]
v = all_data['Volume'].apply(np.log1p)
v = v.diff()
d.append(v)
d = np.hstack([x.values for x in d])
d.shape
# Out:
# (2507, 265)

# %% [markdown]
# ### Выход

# %%
outDataHigh = (all_data['High'] / all_data['Close'].shift(1)).values
outDataLow = (all_data['Low'] / all_data['Close'].shift(1)).values

# %% [markdown]
# ## Первый вход в окно (без сдвига)

# %%
WINDOW = 10
# d = pd.DataFrame(inpData1)
# inpData1 = np.hstack([d.shift(n).values for n in range(WINDOW)])
# inpData1.shape
inpData1 = np.ones((*d.shape,WINDOW))
d = pd.DataFrame(d)
for n in range(WINDOW):
    inpData1[...,n] = d.shift(n).values
inpData1.shape
# Out:
# (2507, 265, 10)

# %% [markdown]
# ## Второй вход - даты (без сдвига)

# %%
days = all_data.index.day.values
weekdays = all_data.index.weekday.values
months = all_data.index.month.values
x2sc = lambda x,per: np.transpose([np.sin(x/per),np.cos(x/per)])
inpData2 = np.hstack([x2sc(days,31),x2sc(weekdays,7),x2sc(months,12)])
inpData2.shape
# Out:
# (2507, 6)

# %% [markdown]
# ## Разделяем обучение и расчет (появляется сдвиг)

# %%
inpData1Calc = inpData1[-1,...]

inpData1Learn = inpData1
inpData1Learn[1:,...] = inpData1Learn[:-1,...]

inpData2Calc = inpData2[-1,...]

inpData2Learn = inpData2
inpData2Learn[1:,...] = inpData2Learn[:-1,...]

# %%
inpData1Learn.shape,inpData2Learn.shape
# Out:
# ((2507, 265, 10), (2507, 6))

# %%
inpData1Calc.shape,inpData2Calc.shape
# Out:
# ((265, 10), (6,))

# %%
outDataHigh.shape
# Out:
# (2507, 53)

# %%
outDataLow.shape
# Out:
# (2507, 53)

# %% [markdown]
# ## Чистим пустоты на обучении

# %%
index = (~np.isnan(np.sum(inpData1Learn,axis=(1,2)))) & (~np.isnan(np.sum(inpData2Learn,axis=1))) & (~np.isnan(np.sum(outDataHigh,axis=1))) & (~np.isnan(np.sum(outDataLow,axis=1)))
np.unique(index,return_counts=True)
# Out:
# (array([False,  True]), array([  11, 2496]))

# %%
inpData1Learn = inpData1Learn[index,:]
inpData2Learn = inpData2Learn[index,:]
outDataHigh = outDataHigh[index,:]
outDataLow = outDataLow[index,:]
learnDates = all_data.index.values[index]

# %%
print('inpData1Learn size',inpData1Learn.shape)
print('inpData2Learn size',inpData2Learn.shape)
print('outDataHigh size',outDataHigh.shape)
print('outDataLow size',outDataLow.shape)
print('Learn dates from',learnDates[0],'to',learnDates[-1])
# Out:
# inpData1Learn size (2496, 265, 10)
# inpData2Learn size (2496, 6)
# outDataHigh size (2496, 53)
# outDataLow size (2496, 53)
# Learn dates from 2011-09-01T00:00:00.000000000 to 2021-08-17T00:00:00.000000000

# %% [markdown]
# ## Разделение на обучение и тест

# %%
X1_train, X1_test, X2_train, X2_test, oH_train, oH_test, oL_train, oL_test, d_train, d_test = train_test_split(inpData1Learn,inpData2Learn,outDataHigh,outDataLow,learnDates,test_size=0.33,shuffle=False)

# %% [markdown]
# ## Нормировка данных (слой нормировки первого входа)

# %%
normLayer = keras.layers.experimental.preprocessing.Normalization(axis=1)
normLayer.adapt(X1_train)

# %% [markdown]
# # Модель

# %% [markdown]
# ## Слои

# %%
input1 = keras.layers.Input(shape=X1_train.shape[1:])
x1 = normLayer(input1)

x1 = keras.layers.Conv1D(WINDOW*2,3,padding='same')(x1)
x1 = keras.layers.AveragePooling1D()(x1)

x1 = keras.layers.Conv1D(WINDOW*2*2,3,padding='same')(x1)
x1 = keras.layers.AveragePooling1D()(x1)

x1 = keras.layers.Conv1D(WINDOW*2*2*2,3,padding='same')(x1)
x1 = keras.layers.AveragePooling1D()(x1)

x1 = keras.layers.Conv1D(WINDOW*2*2*2*2,3,padding='same')(x1)
x1 = keras.layers.AveragePooling1D()(x1)

x1 = keras.layers.GlobalAveragePooling1D()(x1)

x1 = keras.layers.Flatten()(x1)

input2 = keras.layers.Input(shape=(X2_train.shape[1],))

x = keras.layers.Concatenate()([x1,input2])

x = keras.layers.Dense(50,activation='relu')(x)
x = keras.layers.Dropout(0.1)(x)

output = keras.layers.Dense(2)(x)

model = keras.Model((input1,input2),output)
model.compile(optimizer=tf.optimizers.Adam(),
              loss=tf.losses.MeanAbsoluteError())
model.summary()
# Out:
# Model: "model_24"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_51 (InputLayer)           [(None, 265, 10)]    0
# __________________________________________________________________________________________________
# normalization_2 (Normalization) (None, 265, 10)      531         input_51[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 265, 20)      620         normalization_2[21][0]
# __________________________________________________________________________________________________
# average_pooling1d_51 (AveragePo (None, 132, 20)      0           conv1d_60[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 132, 40)      2440        average_pooling1d_51[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_52 (AveragePo (None, 66, 40)       0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 66, 80)       9680        average_pooling1d_52[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_53 (AveragePo (None, 33, 80)       0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 33, 160)      38560       average_pooling1d_53[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_54 (AveragePo (None, 16, 160)      0           conv1d_63[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_11 (Gl (None, 160)          0           average_pooling1d_54[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 160)          0           global_average_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# input_52 (InputLayer)           [(None, 6)]          0
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 166)          0           flatten_24[0][0]
#                                                                  input_52[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 50)           8350        concatenate_24[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 50)           0           dense_39[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 2)            102         dropout_8[0][0]
# ==================================================================================================
# Total params: 60,283
# Trainable params: 59,752
# Non-trainable params: 531
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# ## Обучение

# %%
cb = [tf.keras.callbacks.EarlyStopping(patience=100,restore_best_weights=True,verbose=True),
      tf.keras.callbacks.ReduceLROnPlateau(patience=90,verbose=True)]
history = model.fit((X1_train,X2_train),(oH_train[:,0],oL_train[:,0]),
                    epochs=1000,
                    validation_split=0.3,
                    callbacks = cb)
# Out:
# Epoch 1/1000
# 37/37 [==============================] - 2s 21ms/step - loss: 0.2809 - val_loss: 0.0540
# Epoch 2/1000
# 37/37 [==============================] - 0s 9ms/step - loss: 0.1125 - val_loss: 0.0469
# Epoch 3/1000
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0947 - val_loss: 0.0249
# Epoch 4/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0855 - val_loss: 0.0250
# Epoch 5/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0803 - val_loss: 0.0229
# Epoch 6/1000
# 37/37 [==============================] - 0s 9ms/step - loss: 0.0786 - val_loss: 0.0285
# Epoch 7/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0759 - val_loss: 0.0248
# Epoch 8/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0721 - val_loss: 0.0392
# Epoch 9/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0744 - val_loss: 0.0447
# Epoch 10/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0708 - val_loss: 0.0291
# Epoch 11/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0679 - val_loss: 0.0169
# Epoch 12/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0685 - val_loss: 0.0280
# Epoch 13/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0695 - val_loss: 0.0165
# Epoch 14/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0639 - val_loss: 0.0177
# Epoch 15/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0667 - val_loss: 0.0159
# Epoch 16/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0630 - val_loss: 0.0279
# Epoch 17/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0595 - val_loss: 0.0153
# Epoch 18/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0606 - val_loss: 0.0231
# Epoch 19/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0624 - val_loss: 0.0177
# Epoch 20/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0582 - val_loss: 0.0148
# Epoch 21/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0591 - val_loss: 0.0161
# Epoch 22/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0548 - val_loss: 0.0148
# Epoch 23/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0570 - val_loss: 0.0207
# Epoch 24/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0566 - val_loss: 0.0188
# Epoch 25/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0569 - val_loss: 0.0242
# Epoch 26/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0551 - val_loss: 0.0141
# Epoch 27/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0577 - val_loss: 0.0484
# Epoch 28/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0550 - val_loss: 0.0316
# Epoch 29/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0538 - val_loss: 0.0173
# Epoch 30/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0509 - val_loss: 0.0140
# Epoch 31/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0534 - val_loss: 0.0218
# Epoch 32/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0503 - val_loss: 0.0161
# Epoch 33/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0498 - val_loss: 0.0152
# Epoch 34/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0476 - val_loss: 0.0137
# Epoch 35/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0499 - val_loss: 0.0225
# Epoch 36/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0470 - val_loss: 0.0129
# Epoch 37/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0487 - val_loss: 0.0178
# Epoch 38/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0477 - val_loss: 0.0167
# Epoch 39/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0451 - val_loss: 0.0127
# Epoch 40/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0443 - val_loss: 0.0128
# Epoch 41/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0462 - val_loss: 0.0334
# Epoch 42/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0472 - val_loss: 0.0165
# Epoch 43/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0447 - val_loss: 0.0122
# Epoch 44/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0424 - val_loss: 0.0195
# Epoch 45/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0431 - val_loss: 0.0145
# Epoch 46/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0440 - val_loss: 0.0124
# Epoch 47/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0415 - val_loss: 0.0148
# Epoch 48/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0424 - val_loss: 0.0127
# Epoch 49/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0414 - val_loss: 0.0143
# Epoch 50/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0424 - val_loss: 0.0118
# Epoch 51/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0403 - val_loss: 0.0124
# Epoch 52/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0402 - val_loss: 0.0117
# Epoch 53/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0411 - val_loss: 0.0120
# Epoch 54/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0426 - val_loss: 0.0119
# Epoch 55/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0389 - val_loss: 0.0123
# Epoch 56/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0371 - val_loss: 0.0148
# Epoch 57/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.
1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0125 - val_loss: 0.0103
# Epoch 181/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0126 - val_loss: 0.0101
# Epoch 182/1000
# 37/37 [==============================] - 1s 14ms/step - loss: 0.0123 - val_loss: 0.0104
# Epoch 183/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0127 - val_loss: 0.0101
# Epoch 184/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0101
# Epoch 185/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0103
# Epoch 186/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 187/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 188/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0101
# Epoch 189/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0123 - val_loss: 0.0101
# Epoch 190/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0122 - val_loss: 0.0103
# Epoch 191/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0123 - val_loss: 0.0105
# Epoch 192/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0123 - val_loss: 0.0105
# Epoch 193/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 194/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 195/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0100
# Epoch 196/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0102
# Epoch 197/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0100
# Epoch 198/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0100
# Epoch 199/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0100
# Epoch 200/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0101
# Epoch 201/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0121 - val_loss: 0.0102
# Epoch 202/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0101
# Epoch 203/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0100
# Epoch 204/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0120 - val_loss: 0.0098
# Epoch 205/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0105
# Epoch 206/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0101
# Epoch 207/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0119 - val_loss: 0.0101
# Epoch 208/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0117 - val_loss: 0.0102
# Epoch 209/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0118 - val_loss: 0.0101
# Epoch 210/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0117 - val_loss: 0.0101
# Epoch 211/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0104
# Epoch 212/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0101
# Epoch 213/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0103
# Epoch 214/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0119 - val_loss: 0.0100
# Epoch 215/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0100
# Epoch 216/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0102
# Epoch 217/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0101
# Epoch 218/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0114 - val_loss: 0.0101
# Epoch 219/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0101
# Epoch 220/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0102
# Epoch 221/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0101
# Epoch 222/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0101
# Epoch 223/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0099
# Epoch 224/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0118 - val_loss: 0.0100
# Epoch 225/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0116 - val_loss: 0.0104
# Epoch 226/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0114 - val_loss: 0.0103
# Epoch 227/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.0102
# Epoch 228/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0101
# Epoch 229/1000
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0112 - val_loss: 0.0100
# Epoch 230/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0112 - val_loss: 0.0103
# Epoch 231/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0111 - val_loss: 0.0102
# Epoch 232/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0106
# Epoch 233/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0105
# Epoch 234/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0112 - val_loss: 0.0104
# Epoch 235/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0111 - val_loss: 0.0101
# Epoch 236/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0102
# Epoch 237/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0111 - val_loss: 0.0102
# Epoch 238/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0112 - val_loss: 0.0103
# Epoch 239/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0112 - val_loss: 0.0102
# Epoch 240/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0110 - val_loss: 0.0105
# Epoch 241/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0111 - val_loss: 0.0102
# Epoch 242/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0109 - val_loss: 0.0103
# Epoch 243/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0109 - val_loss: 0.0104
# Epoch 244/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0105
# Epoch 245/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0109 - val_loss: 0.0104
# Epoch 246/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0108 - val_loss: 0.0106
# Epoch 247/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0109 - val_loss: 0.0102
# Epoch 248/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0103
# Epoch 249/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 250/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0107 - val_loss: 0.0105
# Epoch 251/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0106 - val_loss: 0.0103
# Epoch 252/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0108 - val_loss: 0.0101
# Epoch 253/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 254/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0106 - val_loss: 0.0103
# Epoch 255/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 256/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 257/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 258/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0105 - val_loss: 0.0102
# Epoch 259/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 260/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 261/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 262/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0107 - val_loss: 0.0103
# Epoch 263/1000
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 264/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0104 - val_loss: 0.0105
# Epoch 265/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 266/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0107 - val_loss: 0.0103
# Epoch 267/1000
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 268/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 269/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 270/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 271/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 272/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0104 - val_loss: 0.0105
# Epoch 273/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 274/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0101 - val_loss: 0.0103
# Epoch 275/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0104 - val_loss: 0.0103
# Epoch 276/1000
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0099 - val_loss: 0.0106
# Epoch 277/1000
# 37/37 [==============================] - 1s 17ms/step - loss: 0.0099 - val_loss: 0.0103
# Epoch 278/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0103
# Epoch 279/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0101 - val_loss: 0.0106
# Epoch 280/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 281/1000
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0104
# Epoch 282/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 283/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 0.0103
# Epoch 284/1000
# 37/37 [==============================] - 0s 13ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 285/1000
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0098 - val_loss: 0.0105
# Epoch 286/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 0.0106
# Epoch 287/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0095 - val_loss: 0.0108
# Epoch 288/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0095 - val_loss: 0.0105
# Epoch 289/1000
# 37/37 [==============================] - 0s 12ms/step - loss: 0.0094 - val_loss: 0.0104
# Epoch 290/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0107
# Epoch 291/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0106
# Epoch 292/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0096 - val_loss: 0.0104
# Epoch 293/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0095 - val_loss: 0.0105
# Epoch 294/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 0.0107
#
# Epoch 00294: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 295/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0093 - val_loss: 0.0105
# Epoch 296/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0089 - val_loss: 0.0104
# Epoch 297/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0087 - val_loss: 0.0104
# Epoch 298/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0086 - val_loss: 0.0105
# Epoch 299/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 0.0105
# Epoch 300/1000
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0084 - val_loss: 0.0105
# Epoch 301/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 0.0105
# Epoch 302/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0105
# Epoch 303/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 0.0105
# Epoch 304/1000
# 37/37 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0106
# Restoring model weights from the end of the best epoch.
# Epoch 00304: early stopping

# %%
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.yscale('log')
plt.legend()
plt.show()

# %%
model.evaluate([X1_test,X2_test],(oH_test[:,0],oL_test[:,0]))
# Out:
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0109
# 0.0108882961794734

# %%
test_res = model([X1_test,X2_test]).numpy()
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.scatterplot(x=oH_test[:,0],y=test_res[:,0])
plt.plot([min(oH_test[:,0]),max(oH_test[:,0])],[min(oH_test[:,0]),max(oH_test[:,0])],':')
plt.title(f'High corr = {np.corrcoef(oH_test[:,0],test_res[:,0])[0,1] :.2f}')

plt.subplot(2,2,2)
sns.scatterplot(x=oL_test[:,0],y=test_res[:,1])
plt.plot([min(oL_test[:,0]),max(oL_test[:,0])],[min(oL_test[:,0]),max(oL_test[:,0])],':')
plt.title(f'Low corr = {np.corrcoef(oL_test[:,0],test_res[:,1])[0,1] :.2f}')
plt.subplot(2,2,3)
sns.residplot(x=oH_test[:,0],y=test_res[:,0])
plt.subplot(2,2,4)
sns.residplot(x=oL_test[:,0],y=test_res[:,1])
plt.show()
